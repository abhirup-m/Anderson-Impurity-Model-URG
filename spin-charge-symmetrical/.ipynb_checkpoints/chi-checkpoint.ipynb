# %% [markdown]
# # Susceptibility
#
# $$
# Z = \sum_n e^{-\beta E_n}\\
# m(B) = \frac{1}{\beta Z} \frac{\partial Z}{\partial B}\\
# \chi = \lim_{B \to 0} \frac{\partial m}{\partial B}
# $$

# %% [markdown]
# ## Eigenvalues and eigenstates in presence of $\vec B$
#
# ### The easy ones: $n=0,1,3,4$
#
# $$
# \newcommand{\ket}[1]{\vert{#1}\rangle}\\
# \newcommand{\bra}[1]{\langle{#1}\vert}\\
# \Delta_{\pm} \equiv \sqrt{v^2 + (\epsilon_d \pm \frac{1}{2}B)^2}\\
# \ket{0,0} \text{ and } \ket{2,2}\begin{cases} E_{0} = E_{15} = \frac{1}{4}k \end{cases}\\
# \text{ between }\ket{\uparrow,0},\ket{0,\uparrow} \text{ and between }\ket{\uparrow,2},\ket{2,\uparrow}\begin{cases}
# E_{1} = E_{11} = \frac{1}{2}\left(\epsilon_d + \frac{1}{2}B + \Delta_{+}\right)\\
# E_{2} = E_{12} = \frac{1}{2}\left(\epsilon_d + \frac{1}{2}B - \Delta_{+}\right)
# \end{cases}\\
# \text{ between }\ket{\downarrow,0},\ket{0,\downarrow} \text{ and between }\ket{\downarrow,2},\ket{2,\downarrow}\begin{cases}
# E_{3} = E_{13} = \frac{1}{2}\left(\epsilon_d - \frac{1}{2}B + \Delta_{-}\right)\\
# E_{4} = E_{14} = \frac{1}{2}\left(\epsilon_d - \frac{1}{2}B - \Delta_{-}\right)
# \end{cases}\\
# $$
#
# ### The easy ones in $n=2$
#
# $$
# \ket{\uparrow, \uparrow}: E_5 = \epsilon_d + \frac{1}{4}j + \frac{1}{2}B\\
# \ket{\downarrow, \downarrow}: E_6 = \epsilon_d + \frac{1}{4}j - \frac{1}{2}B\\
# \ket{\text{charge triplet 0}}: E_7 = \frac{1}{4}k\\
# $$
#
# ### The remaining subspace
#
# $$
# \begin{pmatrix}
#     \epsilon_d+\frac{1}{4}j & B & 0\\
#     B & \epsilon_d - \frac{3}{4}j & -2v\\
#     0 & -2v & -\frac{3}{4}k
# \end{pmatrix}
# $$
# The basis is: $\ket{\text{spin trip. } 0}, \ket{\text{spin singl.}}, \ket{\text{charge singl.}}$
#
# The next step is to diagonalize this matrix.

# %%
from sympy import *
init_printing(use_unicode=True)
ed,j,k,v,B,E,beta,x = symbols('ed J k v B E beta x')

# %%
M = Matrix([[ed + j/4, B, 0], [B, ed - 3*j/4, -2*v], [0, -2*v, -3*k/4]])
charp = M.charpoly(x)
sols = solve(charp, x)

# %%
delta_p = sqrt(v**2 + (ed + B/2)**2)
delta_m = sqrt(v**2 + (ed - B/2)**2)
Es = [[]]*16
Es[0] = Es[15] = k/8 + k/8
Es[1] = Es[11] = (ed + B/2 + delta_p)/2
Es[2] = Es[12] = (ed + B/2 - delta_p)/2
Es[3] = Es[13] = (ed - B/2 + delta_m)/2
Es[4] = Es[14] = (ed - B/2 - delta_m)/2
Es[5] = ed + j/4 + B/2
Es[6] = ed + j/4 - B/2
Es[7] = k/4
Es[8] = sols[0]
Es[9] = sols[1]
Es[10] = sols[2]

# %%
Z = 0
for E in Es:
    Z += exp(-beta*E)
m = (1/beta)*diff(Z, B)/Z
chi = limit(diff(m, B), B, 0)
chi
# Out:
# <class 'sympy.core.mul.Mul'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.mul.Mul'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.add.Add'>
# <class 'sympy.core.mul.Mul'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-50-8bdd5127c0e9> in <module>
#       4     Z += exp(-beta*E)
#       5 m = (1/beta)*diff(Z, B)/Z
# ----> 6 chi = limit(diff(m, B), B, 0)
#
# /usr/lib/python3.9/site-packages/sympy/series/limits.py in limit(e, z, z0, dir)
#      61     """
#      62
# ---> 63     return Limit(e, z, z0, dir).doit(deep=False)
#      64
#      65
#
# /usr/lib/python3.9/site-packages/sympy/series/limits.py in doit(self, **hints)
#     327                             % (l, r))
#     328             else:
# --> 329                 r = gruntz(e, z, z0, dir)
#     330             if r is S.NaN or l is S.NaN:
#     331                 raise PoleError()
#
# /usr/lib/python3.9/site-packages/sympy/series/gruntz.py in gruntz(e, z, z0, dir)
#     682
#     683     try:
# --> 684         r = limitinf(e0, z)
#     685     except ValueError:
#     686         r = limitinf(e0, z, leadsimp=True)
#
# /usr/lib/python3.9/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError:
#      74                 retval = func(*args, **kwargs)
#
# /usr/lib/python3.9/site-packages/sympy/series/gruntz.py in limitinf(e, x, leadsimp)
#     447     e = e.rewrite('tractable', deep=True, limitvar=x)
#     448     e = powdenest(e)
# --> 449     c0, e0 = mrv_leadterm(e, x)
#     450     sig = sign(e0, x)
#     451     if sig == 1:
#
# /usr/lib/python3.9/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      70         def wrapper(*args, **kwargs):
#      71             try:
# ---> 72                 retval = cfunc(*args, **kwargs)
#      73             except TypeError:
#      74                 retval = func(*args, **kwargs)
#
# /usr/lib/python3.9/site-packages/sympy/series/gruntz.py in mrv_leadterm(e, x)
#     510         return (e, S.Zero)
#     511     if Omega == SubsSet():
# --> 512         Omega, exps = mrv(e, x)
#     513     if not Omega:
#     514         # e really does not depend on x after simplification
#
# /usr/lib/python3.9/site-packages/sympy/series/gruntz.py in mrv(e, x)
#     260             return s, e.func(i, expr)
#     261         a, b = d.as_two_terms()
# --> 262         s1, e1 = mrv(a, x)
#     263         s2, e2 = mrv(b, x)
#     264         return mrv_max1(s1, s2, e.func(i, e1, e2), x)
#
# /usr/lib/python3.9/site-packages/sympy/series/gruntz.py in mrv(e, x)
#     246     """Returns a SubsSet of most rapidly varying (mrv) subexpressions of 'e',
#     247        and e rewritten in terms of these"""
# --> 248     e = powsimp(e, deep=True, combine='exp')
#     249     if not isinstance(e, Basic):
#     250         raise TypeError("e should be an instance of Basic")
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     139                 b, e = term.as_base_exp()
#     140                 if deep:
# --> 141                     b, e = [recurse(i) for i in [b, e]]
#     142                 if b.is_Pow or isinstance(b, exp):
#     143                     # don't let smthg like sqrt(x**a) split into x**a, 1/2
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     139                 b, e = term.as_base_exp()
#     140                 if deep:
# --> 141                     b, e = [recurse(i) for i in [b, e]]
#     142                 if b.is_Pow or isinstance(b, exp):
#     143                     # don't let smthg like sqrt(x**a) split into x**a, 1/2
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     114
#     115     if deep or expr.is_Add or expr.is_Mul and _y not in expr.args:
# --> 116         expr = expr.func(*[recurse(w) for w in expr.args])
#     117
#     118     if expr.is_Pow:
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#     139                 b, e = term.as_base_exp()
#     140                 if deep:
# --> 141                     b, e = [recurse(i) for i in [b, e]]
#     142                 if b.is_Pow or isinstance(b, exp):
#     143                     # don't let smthg like sqrt(x**a) split into x**a, 1/2
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in <listcomp>(.0)
#     139                 b, e = term.as_base_exp()
#     140                 if deep:
# --> 141                     b, e = [recurse(i) for i in [b, e]]
#     142                 if b.is_Pow or isinstance(b, exp):
#     143                     # don't let smthg like sqrt(x**a) split into x**a, 1/2
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in recurse(arg, **kwargs)
#     105         _force = kwargs.get('force', force)
#     106         _measure = kwargs.get('measure', measure)
# --> 107         return powsimp(arg, _deep, _combine, _force, _measure)
#     108
#     109     expr = sympify(expr)
#
# /usr/lib/python3.9/site-packages/sympy/simplify/powsimp.py in powsimp(expr, deep, combine, force, measure)
#      13
#      14
# ---> 15 def powsimp(expr, deep=False, combine='all', force=False, measure=count_ops):
#      16     """
#      17     reduces expression by combining powers with similar bases and exponents.
#
# KeyboardInterrupt:
